# %% [markdown]
# <a href="https://colab.research.google.com/github/krishatuladhar/ML_From_Scratch/blob/main/Intro%20to%20Panda/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Pandas
# Data Preprocessing in Machine Learning using Pandas
#  Data processing is required tasks for cleaning the data and making it suitable for a machine learning model which also increase the accuracy and efficiency of a machine learning model.
#  Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data,in order to transform them into a standard and normalized format,
#  preprocessing involves the following aspects:
#   - missing values
#   - data standardization
#   - data normalization
#   - data mining

# %%
import pandas as pd

# %%
data = {
    "cars": ["bmw", "honda", "suzuki", "BYD"],
    "models": ["2007", "2009", "2008", "2023"],
    "passenger": ["5", "5", "6", "7"]
}
print(data)
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'BYD'], 'models': ['2007', '2009', '2008', '2023'], 'passenger': ['5', '5', '6', '7']}

# %%
#convert the data into dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     bmw   2007         5
# 1   honda   2009         5
# 2  suzuki   2008         6
# 3     BYD   2023         7

# %%
# save the file as a csv file
df.to_csv("/content/drive/MyDrive/asian 6th sem/mlscratch/car_data.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# Pandas Series
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# Create labels in pandas with index
a = [1, 7, 2]
myvar = pd.Series(a, index=["x", "y", "z"])
myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["x"])
# Out:
# 1

# %%
#task: Create a dataframe named df, with data calories and durations.
data = {
    "calories": ["40", "20", "300"],
    "duration": ["20", "10", "10"]
}
df = pd.DataFrame(data)
df
# Out:
#   calories duration
# 0       40       20
# 1       20       10
# 2      300       10

# %%
df.to_csv("/content/drive/MyDrive/asian 6th sem/mlscratch/duration.csv")

# %%
print(df.loc[1])
# Out:
# calories    20
# duration    10
# Name: 1, dtype: object

# %%
print(df.loc[[0,1]])
# Out:
#   calories duration
# 0       40       20
# 1       20       10

# %%
import pandas as pd
data = {
    "calories": ["40", "20", "300"],
    "duration": ["20", "10", "10"]
}
df = pd.DataFrame(data,  index=["day1", "day2", "day3"])
df
# Out:
#      calories duration
# day1       40       20
# day2       20       10
# day3      300       10

# %%
print(df.loc["day2"])
# Out:
# calories    20
# duration    10
# Name: day2, dtype: object

# %%
# clean pandas_dataset.csv
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.head()
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0

# %%
df.tail()
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
df.shape
# Out:
# (32, 5)

# %%
data_types=df.dtypes
data_types
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
isnull= df.isnull()
isnull_count = isnull.sum()
print("Total number of null values:", isnull_count)
# Out:
# Total number of null values: Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#total nulls in dataset
total_isnull_count = isnull.sum().sum()
print("Total nulls:",total_isnull_count)
# Out:
# Total nulls: 3

# %%
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
#replace single quote with blank and make the data formatted
df["Date"] = df["Date"].replace("'","", regex = True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#handle null values, return dataframe with no empty cells
# we can use df.dropna(), it removes empty cells but will not change the dataframe
#if we want data frame to be changed, simply use inplace=True
new_df= df.dropna()
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
isnull_count_newdf = new_df.isnull().sum()
print(isnull_count_newdf)
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#another way of handling the null values is by replacing the null values
df.fillna(130, inplace=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
df["Calories"].fillna(130, inplace= True)
df
# Out:
# <ipython-input-33-17a5022d96a2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(130, inplace= True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# ...

# %%
# fill specific with mean, median and mode
df = pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
x = df["Calories"].mean()
df["Calories"].fillna(x, inplace = True)
df
# Out:
# <ipython-input-34-887b9bc82407>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(x, inplace = True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130    409.10
# 1         60  2020/12/02'    117       145    479.00
# 2         60  2020/12/03'    103       135    340.00
# 3         45  2020/12/04'    109       175    282.40
# 4         45  2020/12/05'    117       148    406.00
# 5         60  2020/12/06'    102       127    300.00
# ...
